# %%
# Clone the repository
# !git clone https://github.com/Sadie3958/econ8310-semester_project.git
# %cd econ8310-semester_project

# Install requirements
# !pip install -r requirements.txt

# Download the weights from the Release section
# !wget https://github.com/Sadie3958/econ8310-semester_project/releases/download/v1.0.0/baseball_weights.pth
# Out:
# Cloning into 'econ8310-semester_project'...
# remote: Enumerating objects: 350, done.
# remote: Counting objects: 100% (70/70), done.
# remote: Compressing objects: 100% (63/63), done.
# remote: Total 350 (delta 27), reused 6 (delta 6), pack-reused 280 (from 1)
# Receiving objects: 100% (350/350), 507.39 MiB | 39.08 MiB/s, done.
# Resolving deltas: 100% (128/128), done.
# Updating files: 100% (149/149), done.
# /content/econ8310-semester_project/econ8310-semester_project
# ...
# --2026-04-25 15:02:26--  https://github.com/Sadie3958/econ8310-semester_project/releases/download/v1.0.0/baseball_weights.pth
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# Run the main script
# !python main.py
# Out:
# --- Starting Baseball Tracking Evaluation ---
# Successfully loaded feature weights from ./baseball_weights.pth (Adjusted for 4-coordinate output)
# Successfully initialized loader with 78 videos and XML annotations.
# Sample Prediction (x, y, w, h): [[-1.7554973363876343, 0.2631625831127167, -1.1264625787734985, -0.4447621703147888]]
# Evaluation Complete. Model is ready for coaching diagnostics.
